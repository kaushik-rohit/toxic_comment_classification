# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('./test2.csv')

# %%
test = test.drop(['Unnamed: 0'], axis=1)
test
# Out:
#                       id                                       comment_text  \
# 0       00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1       0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2       00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3       00017563c3f7919a  :If you have a look back at the source, the in...
# 4       00017695ad8997eb          I don't anonymously edit articles at all.
# ...                  ...                                                ...
# 153159  fffcd0960ee309b5  . \n i totally agree, this stuff is nothing bu...
# 153160  fffd7a9a6eb32c16  == Throw from out field to home plate. == \n\n...
# 153161  fffda9e8d6fafa9e  " \n\n == Okinotorishima categories == \n\n I ...
# 153162  fffe8f1340a79fc2  " \n\n == ""One of the founding nations of the...
# 153163  ffffce3fb183ee80  " \n :::Stop already. Your bullshit is not wel...
#
# ...

# %%
test['prediction'] = test.apply(lambda x: np.fromstring(x['prediction'][1:-1].strip(), dtype='float', sep=' '), axis=1)

# %%
rows = []
for index, row in test.iterrows():
    id_ = row['id']
    preds = row['prediction']
    if len(preds) == 5:
        preds = [0, 0, 0, 0, 0, 0]
    rows += [[id_, preds[0], preds[1], preds[2], preds[3], preds[4], preds[5]]]

# %%
df = pd.DataFrame(rows, columns=['id', 'toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate'])

# %%
df
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  0.995389      0.302700  0.972525  0.057024
# 1       0000247867823ef7  0.001497      0.000190  0.000588  0.000221
# 2       00013b17ad220c46  0.001121      0.000233  0.000617  0.000263
# 3       00017563c3f7919a  0.000819      0.000272  0.000502  0.000344
# 4       00017695ad8997eb  0.002022      0.000183  0.000636  0.000212
# ...                  ...       ...           ...       ...       ...
# 153159  fffcd0960ee309b5  0.526018      0.002829  0.207518  0.000771
# 153160  fffd7a9a6eb32c16  0.002475      0.000167  0.000671  0.000195
# 153161  fffda9e8d6fafa9e  0.000870      0.000284  0.000500  0.000323
# 153162  fffe8f1340a79fc2  0.001235      0.000218  0.000509  0.000285
# 153163  ffffce3fb183ee80  0.933901      0.017842  0.762678  0.002203
#
#           insult  identity_hate
# 0       0.930166       0.478233
# 1       0.000454       0.000288
# 2       0.000448       0.000343
# ...

# %%
df.to_csv('predictions.csv')
